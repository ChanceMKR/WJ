# %%
from openai import OpenAI
import pandas as pd
from pathlib import Path
from tqdm import tqdm
import json
import re

# API 및 모델
client = OpenAI(api_key="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")
MODEL_NAME = "gpt-4o-mini"

# 경로
base_dir = Path("./data")
output_dir = Path('./result')
info_path = base_dir / "학생정보.csv"
cluster_path = base_dir / "클러스터_메타.csv"
segment_path = base_dir / "세그먼트_메타.csv"

# %%
# 데이터 로드
df_info = pd.read_csv(info_path)
df_cluster = pd.read_csv(cluster_path)
df_segment = pd.read_csv(segment_path)

# cstmr_id 기준 병합 (학생정보 + 클러스터 + 세그먼트)
df_merged = (
    df_info
    .merge(df_cluster, on="cstmr_id", how="left", suffixes=('', '_cluster'))
    .merge(df_segment, on="cstmr_id", how="left", suffixes=('', '_segment'))
)

# %% [markdown]
# ## 학습전략 TEST

# %%
from openai import OpenAI

# API 및 모델
client = OpenAI(api_key="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")
MODEL_NAME = "gpt-4o-mini"

# %% [markdown]
# (0) 기본

# %%
prompt = f"""
핵심전략 : (자율성 존중, 관계중심 몰입 + 자기성찰, 학습의 의미화, 자기효능감 강화)

위의 핵심전략을 보고 구체적 방향 뽑아줘
예시 : 1. 스스로 계획 세우기 유도 2. 오픈형 질문활용
"""

# %%
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "system", "content": "당신은 초등학생 맞춤 학습 멘토입니다."},
        {"role": "user", "content": prompt}
    ],
    temperature=0.7,
    max_tokens=200
)
print(response.choices[0].message.content)
# Out:
# 아래는 제시된 핵심전략을 바탕으로 한 구체적인 방향입니다:
#
# 1. **자율성 존중**
#    - **스스로 목표 설정하기**: 학생들이 자신의 학습 목표를 설정하고 이를 이루기 위한 계획을 세우도록 유도합니다.
#    - **선택권 제공하기**: 과제나 프로젝트 선택 시 여러 옵션을 제공하여 학생들이 스스로 선택할 수 있도록 합니다.
#
# 2. **관계중심 몰입**
#    - **협동 학습 활동**: 팀 프로젝트나 그룹 토론을 통해 학생들이 서로 협력하고 소통할 수 있는 기회를 제공합니다.
#    - **멘토링 프로그램**: 상급생이나 교사와의 멘토링 관계를 통해 긍정적인 관계를 형성할 수 있도록 지원합니다.
#
# 3. **자기성찰**
#    - **일지 작성하기**: 매일 또는 매주 학습한 내용을

# %% [markdown]
# 수현

# %%
import pandas as pd

# 전략 데이터 정의
cluster_strategies = [
    {
        "cluster_id": 1,
        "core_integrated_strategy": "자기주도적으로 학습을 조절하고 몰입할 수 있는 강점을 살려, 자율성과 성취 경험을 강화하여 내적 동기를 유지하는 전략"
    },
    {
        "cluster_id": 2,
        "core_integrated_strategy": "전략적으로 성과를 잘 내나 규칙성과 복습이 부족하므로 학습 중요성 강조와 환경적 구조를 통해 학습 루틴과 자기점검 습관을 형성하는 전략"
    },
    {
        "cluster_id": 3,
        "core_integrated_strategy": "주어진 과제는 성실히 수행하나, 복습까지 이어지지 않기에 외적 책임을 부여하여 학습 지속력을 높이는 전략"
    },
    {
        "cluster_id": 4,
        "core_integrated_strategy": "낮은 학습 동기를 회복할 수 있도록, 소규모 성취 경험과 안정적인 학습 루틴을 제공하고, 외적 책임감을 통해 점진적으로 학습을 형성하는 전략"
    },
    {
        "cluster_id": 5,
        "core_integrated_strategy": "학습 회피 성향을 고려하여, 호기심과 흥미 중심의 참여를 유도하고, 정서적 안정과 실수 허용 환경 속에서 학습 시작을 유도하는 전략"
    }
]

# 데이터프레임 생성
Strategic_Df = pd.DataFrame(cluster_strategies)

# 결과 확인
Strategic_Df
# Out:
#    cluster_id                           core_integrated_strategy
# 0           1  자기주도적으로 학습을 조절하고 몰입할 수 있는 강점을 살려, 자율성과 성취 경험을 ...
# 1           2  전략적으로 성과를 잘 내나 규칙성과 복습이 부족하므로 학습 중요성 강조와 환경적 구...
# 2           3  주어진 과제는 성실히 수행하나, 복습까지 이어지지 않기에 외적 책임을 부여하여 학습...
# 3           4  낮은 학습 동기를 회복할 수 있도록, 소규모 성취 경험과 안정적인 학습 루틴을 제공...
# 4           5  학습 회피 성향을 고려하여, 호기심과 흥미 중심의 참여를 유도하고, 정서적 안정과 ...

# %% [markdown]
# (1) 기본

# %%
import re

# 결과 저장 리스트
detailed_strategies = []

# 전략 생성 반복
for _, row in Strategic_Df.iterrows():
    cluster_id = row["cluster_id"]
    strategy = row["core_integrated_strategy"]

    prompt = f"""
    core_integrated_strategy: "{strategy}"

    각 cluster_id 별로 core_integrated_strategy을 바탕으로 아래 전략을 작성해주세요.
    1. praise_strategy: 상승한 지표에 대한 칭찬 전략
    2. alert_strategy: 하락한 지표에 대한 채찍 전략
    3. wrong_answer_guidance: 오답에 대한 것을 언급하는 전략
    4. weekly_guidance: 이번 주 학습 수행에 필요한 전반적인 행동 전략

    반드시 각 항목은 '~하기'로 끝나는 문장으로 작성하고, 번호 형식을 반드시 유지해주세요.
    """

    response = client.chat.completions.create(
        model=MODEL_NAME,
        messages=[
            {"role": "system", "content": "당신은 초등학생 맞춤 온라인 학습 멘토입니다."},
            {"role": "user", "content": prompt}
        ],
        temperature=0.7,
        max_tokens=300
    )

    content = response.choices[0].message.content.strip()

    # 각 줄을 파싱해서 전략 추출
    lines = [line.strip() for line in content.split("\n") if line.strip()]
    strategies = ["", "", "", ""]

    for line in lines:
        match = re.match(r"^\s*(\d+)\.\s*(.+)", line)
        if match:
            idx = int(match.group(1)) - 1
            if 0 <= idx <= 3:
                # 콜론(:)이 있는 경우 앞 접두어 제거
                raw_text = match.group(2)
                strategies[idx] = raw_text.split(":", 1)[-1].strip()

    detailed_strategies.append({
        "cluster_id": cluster_id,
        "praise_strategy": strategies[0],
        "alert_strategy": strategies[1],
        "wrong_answer_guidance": strategies[2],
        "weekly_guidance": strategies[3]
    })

# %%
Detailed_Df = pd.DataFrame(detailed_strategies)
Detailed_Df
# Out:
#    cluster_id                                    praise_strategy  \
# 0           1                        자율적으로 학습 계획을 세운 것에 대해 칭찬하기.
# 1           2                                      작은 성과에도 큰 칭찬을
# 2           3                                    상승한 지표에 대해 칭찬하기
# 3           4                                노력한 결과가 좋아진 점을 강조하며
# 4           5  상승한 지표에 대해 칭찬하며, "너의 노력과 호기심이 정말 멋져, 계속 이렇게 해보...
#
#                                       alert_strategy  \
# 0                    자율성이 떨어진 경우, 스스로 점검하고 동기를 부여하기.
# 1                       성과가 떨어진 부분에 대해 다시 집중하도록 촉구하기
# 2                                 하락한 지표에 대해 경각심을 주기
# 3        목표에 도달하지 못한 경우, 다음 주에는 더 많은 노력을 기울이도록 촉구하기.
# 4  하락한 지표에 대해 "이번에는 조금 아쉬웠지만, 다음에는 더 잘할 수 있도록 준비해...
#
#                                wrong_answer_guidance  \
# 0                오답을 통해 몰입이 부족했음을 인식하고 더 집중하도록 안내하기.
# 1                          오답을 함께 분석하며 올바른 답을 찾도록 돕기
# 2                              오답에 대해 다시 한번 생각해보게 하기
# ...

# %% [markdown]
# (2)
# - 간결하고 일관된 출력 위해서 tem -> 0.5, max -> 200로 줄임
# - core_integrated_strategy 반영해달라고 명시
# - 지표 설명: 상승, 하락지표 상세히 (학습완료율, 출석율, 정답율 등)
# - 예시를 줌

# %%
import re

# 결과 저장 리스트
detailed_strategies = []

# 전략 생성 반복
for _, row in Strategic_Df.iterrows():
    cluster_id = row["cluster_id"]
    strategy = row["core_integrated_strategy"]

    prompt = f"""
    core_integrated_strategy: "{strategy}"

    각 cluster_id 별로 core_integrated_strategy을 바탕으로 아래 전략을 작성해주세요.
    반드시 cluster_id 별로 차별점이 있는 core_integrated_strategy를 반영해야합니다.
    
    1. praise_strategy: 상승한 지표(학습완료율, 출석율, 정답율 등)에 대한 칭찬 전략
    2. alert_strategy: 하락한 지표(학습완료율, 출석율, 정답율 등)에 대한 채찍 전략
    3. wrong_answer_guidance: 오답에 대한 것을 언급하는 전략
    4. weekly_guidance: 이번 주 학습 수행에 필요한 전반적인 행동 전략

    형식: 반드시 각 항목은 예시처럼 '~하기'로 끝나는 간결한 문장으로 작성.
    예시: 
    1. praise_strategy: 성실한 태도를 칭찬하기  
    2. alert_strategy: 부족한 부분을 점검하기  
    3. wrong_answer_guidance: 오답을 정리해보기  
    4. weekly_guidance: 학습 목표를 설정하고 실천하기

    """

    response = client.chat.completions.create(
        model=MODEL_NAME,
        messages=[
            {"role": "system", "content": "당신은 초등학생 맞춤 온라인 학습 멘토입니다."},
            {"role": "user", "content": prompt}
        ],
        temperature=0.5,
        max_tokens=200
    )

    content = response.choices[0].message.content.strip()

    # 각 줄을 파싱해서 전략 추출
    lines = [line.strip() for line in content.split("\n") if line.strip()]
    strategies = ["", "", "", ""]

    for line in lines:
        match = re.match(r"^\s*(\d+)\.\s*(.+)", line)
        if match:
            idx = int(match.group(1)) - 1
            if 0 <= idx <= 3:
                # 콜론(:)이 있는 경우 앞 접두어 제거
                raw_text = match.group(2)
                strategies[idx] = raw_text.split(":", 1)[-1].strip()

    detailed_strategies.append({
        "cluster_id": cluster_id,
        "praise_strategy": strategies[0],
        "alert_strategy": strategies[1],
        "wrong_answer_guidance": strategies[2],
        "weekly_guidance": strategies[3]
    })

# %%
Detailed_Df = pd.DataFrame(detailed_strategies)
Detailed_Df
# Out:
#    cluster_id         praise_strategy            alert_strategy  \
# 0           1     스스로 선택한 학습 방법을 칭찬하기          몰입이 떨어진 순간을 돌아보기
# 1           2    학습 환경을 잘 조성한 점을 칭찬하기
# 2           3      학습의 깊이를 높인 점을 칭찬하기
# 3           4                  규칙적인 학         그룹 활동 참여 부족을 지적하기
# 4           5  실수에도 불구하고 도전한 노력을 칭찬하기  자신감을 잃지 않도록 부족한 부분을 점검하기
#
#   wrong_answer_guidance     weekly_guidance
# 0  오답을 다시 풀어보며 집중력을 높이기   매일 30분 이상 집중 학습하기
# 1    오답을 스스로 찾아보기를 권장하기   주간 학습 계획을 세우고 지키기
# 2     오답의 이유를 찾아보며 복습하기   주간 학습 계획을 세워 실천하기
# 3    오답의 이유를 친구와 이야기해보기  매주 팀 목표를 설정하고 공유하기
# 4    오답을 통해 배운 점을 정리해보기  매일 작은 목표를 세우고 성취하기

# %%
# -> 파싱 오류 JSON 형식으로 바꾸면 괜찮을 가능성 많음

# %% [markdown]
# (3)
# - max -> 350
# - 예시 길게

# %%
import re

# 결과 저장 리스트
detailed_strategies = []

# 전략 생성 반복
for _, row in Strategic_Df.iterrows():
    cluster_id = row["cluster_id"]
    strategy = row["core_integrated_strategy"]

    # 프롬프트 구성
    prompt = f"""
다음은 해당 cluster_id의 핵심 전략입니다:
\"\"\"{strategy}\"\"\"

당신은 초등학생 맞춤 온라인 학습 멘토입니다. 위 전략을 바탕으로 각 항목을 반드시 다르게 구성하고,
전략의 핵심 내용을 반영하여 구체적이고 차별화된 학습 전략을 작성해주세요.

반드시 각 항목은 '~하기'로 끝나는 짧고 명확한 문장으로 작성하고,
번호와 항목 이름 형식을 정확히 지켜주세요.

1. praise_strategy: 상승한 지표(학습완료율, 출석률, 정답률 등)에 대한 칭찬 전략
2. alert_strategy: 하락한 지표(학습완료율, 출석률, 정답률 등)에 대한 채찍 전략
3. wrong_answer_guidance: 오답에 대한 것을 언급하는 전략
4. weekly_guidance: 이번 주 학습 수행에 필요한 전반적인 행동 전략

형식 예시 (내용은 복붙 금지):
1. praise_strategy: 꾸준히 복습한 점을 칭찬하기
2. alert_strategy: 부족한 개념을 다시 점검하기
3. wrong_answer_guidance: 오답 노트를 정리하기
4. weekly_guidance: 매일 정해진 시간에 공부하기
"""

    # GPT 호출
    response = client.chat.completions.create(
        model=MODEL_NAME,
        messages=[
            {"role": "system", "content": "당신은 초등학생 맞춤 온라인 학습 멘토입니다."},
            {"role": "user", "content": prompt}
        ],
        temperature=0.7,
        max_tokens=500
    )

    content = response.choices[0].message.content.strip()

    # 각 줄 파싱
    lines = [line.strip() for line in content.split("\n") if line.strip()]
    strategies = ["", "", "", ""]

    for line in lines:
        # 번호 + 콜론 or 하이픈 형식 허용
        match = re.match(r"^\s*(\d+)[\.\)]?\s*(?:\w+_strategy)?\s*[:\-]?\s*(.+)", line)
        if match:
            idx = int(match.group(1)) - 1
            if 0 <= idx <= 3:
                strategies[idx] = match.group(2).strip()

    # 결과 저장
    detailed_strategies.append({
        "cluster_id": cluster_id,
        "praise_strategy": strategies[0],
        "alert_strategy": strategies[1],
        "wrong_answer_guidance": strategies[2],
        "weekly_guidance": strategies[3]
    })

# %%
Detailed_Df = pd.DataFrame(detailed_strategies)
Detailed_Df
# Out:
#    cluster_id         praise_strategy        alert_strategy  \
# 0           1  목표한 학습 목표를 달성한 점을 칭찬하기  예전보다 낮아진 출석률을 다시 올리기
# 1           2      학습 목표를 달성한 점을 칭찬하기  출석률이 낮은 날을 기록하고 개선하기
# 2           3      목표를 초과 달성한 점을 칭찬하기   목표에 미치지 못한 점을 재조명하기
# 3           4   목표 달성을 위해 노력한 점을 칭찬하기     부족한 부분을 체크하여 보완하기
# 4           5       실수해도 괜찮았던 점을 칭찬하기  목표 달성을 위해 더 열심히 노력하기
#
#                          wrong_answer_guidance  \
# 0          wrong_answer_guidance: 오답의 이유를 분석하기
# 1   wrong_answer_guidance: 오답을 다시 풀어보며 문제 이해하기
# 2        wrong_answer_guidance: 틀린 문제를 다시 풀어보기
# 3  wrong_answer_guidance: 잘못된 문제를 다시 풀어보며 이해하기
# 4         wrong_answer_guidance: 오답의 이유를 생각해보기
#
#                          weekly_guidance
# 0    weekly_guidance: 매일 학습 계획을 세우고 실천하기
# 1   weekly_guidance: 매일 같은 시간에 학습 루틴 만들기
# 2    weekly_guidance: 매일 학습 계획을 세우고 실천하기
# 3     weekly_guidance: 매일 학습 계획을 세워 실천하기
# 4  weekly_guidance: 매일 흥미로운 주제를 선택해 공부하기

# %% [markdown]
# (4)

# %%
import re

# 결과 저장 리스트
detailed_strategies = []

# 전략 생성 반복
for _, row in Strategic_Df.iterrows():
    cluster_id = row["cluster_id"]
    strategy = row["core_integrated_strategy"]

    # 프롬프트 구성
    prompt = f"""
다음은 cluster_id {cluster_id}번 학습자 그룹의 핵심 전략입니다:
\"\"\"{strategy}\"\"\"

당신은 초등학생 맞춤 온라인 학습 멘토입니다. 위 전략을 반드시 반영하여 아래 4가지 전략을 작성해주세요.

[요청 사항]
- 출력은 반드시 숫자만 포함된 번호 (1. 2. 3. 4.)로 시작하세요.
- 각 문장은 '~하기'로 끝나는 한 문장으로 작성하세요.
- 항목명(praise_strategy 등)은 절대 포함하지 마세요.
- 전략은 모두 위 핵심 전략을 기반으로 차별화되어야 합니다.

[출력 예시] (형식만 참고, 내용은 복붙 금지)
1. 꾸준히 복습한 점을 칭찬하기
2. 부족한 개념을 다시 점검하기
3. 오답 노트를 정리하기
4. 매일 정해진 시간에 공부하기
"""

    # GPT 호출
    response = client.chat.completions.create(
        model=MODEL_NAME,
        messages=[
            {"role": "system", "content": "당신은 초등학생 맞춤 온라인 학습 멘토입니다."},
            {"role": "user", "content": prompt}
        ],
        temperature=0.7,
        max_tokens=500
    )

    content = response.choices[0].message.content.strip()

    # 응답 줄 파싱
    lines = [line.strip() for line in content.split("\n") if line.strip()]
    strategies = ["", "", "", ""]

    for line in lines:
        # 1. ~하기 형식 파싱 (항목명 없이)
        match = re.match(r"^\s*(\d+)[\.\)]\s*(.+)", line)
        if match:
            idx = int(match.group(1)) - 1
            if 0 <= idx <= 3:
                strategies[idx] = match.group(2).strip()

    # 결과 저장
    detailed_strategies.append({
        "cluster_id": cluster_id,
        "praise_strategy": strategies[0],
        "alert_strategy": strategies[1],
        "wrong_answer_guidance": strategies[2],
        "weekly_guidance": strategies[3]
    })


strategies_df = pd.DataFrame(detailed_strategies)
strategies_df

# %% [markdown]
# (5)

# %%
# 결과 저장 리스트
detailed_strategies = []

# 전략 생성 반복
for _, row in Strategic_Df.iterrows():
    cluster_id = row["cluster_id"]
    strategy = row["core_integrated_strategy"]

    # 프롬프트 구성
    prompt = f"""
다음은 cluster_id {cluster_id}번 학습자 그룹의 핵심 전략입니다:
\"\"\"{strategy}\"\"\"

당신은 초등학생 맞춤 온라인 학습 멘토입니다. 위 전략을 반드시 반영하여 아래 4가지 전략을 작성해주세요.

[요청 사항]
- 출력은 반드시 숫자만 포함된 번호 (1. 2. 3. 4.)로 시작하세요.
- 각 문장은 '~하기'로 끝나는 문장으로 두 문장을 작성하세요.
- 항목명(praise_strategy 등)은 절대 포함하지 마세요.
- 전략은 모두 위 핵심 전략을 기반으로 차별화되어야 합니다.

[출력 예시] (형식만 참고, 내용은 복붙 금지)
1. 꾸준히 복습한 점을 칭찬하기
2. 부족한 개념을 다시 점검하기
3. 오답 노트를 정리하기
4. 매일 정해진 시간에 공부하기
"""

    # GPT 호출
    response = client.chat.completions.create(
        model=MODEL_NAME,
        messages=[
            {"role": "system", "content": "당신은 학습 전략을 생성해내는 교육 기획자 입니다. 각 클러스터에 맞는 목표를 달성하기 위한 새로운 전략을 만들어야 합니다."},
            
            {"role": "user", "content": prompt}
        ],
        temperature=1,
        max_tokens=500
    )

    content = response.choices[0].message.content.strip()

    # 응답 줄 파싱
    lines = [line.strip() for line in content.split("\n") if line.strip()]
    strategies = ["", "", "", ""]

    for line in lines:
        # 1. ~하기 형식 파싱 (항목명 없이)
        match = re.match(r"^\s*(\d+)[\.\)]\s*(.+)", line)
        if match:
            idx = int(match.group(1)) - 1
            if 0 <= idx <= 3:
                strategies[idx] = match.group(2).strip()

    # 결과 저장
    detailed_strategies.append({
        "cluster_id": cluster_id,
        "praise_strategy": strategies[0],
        "alert_strategy": strategies[1],
        "wrong_answer_guidance": strategies[2],
        "weekly_guidance": strategies[3]
    })


strategies_df = pd.DataFrame(detailed_strategies)
strategies_df

# %%
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "system", "content": "당신은 초등학생 맞춤 온라인 학습 멘토입니다."},
        {"role": "user", "content": prompt}
    ],
    temperature=0.5,
    max_tokens=300
)
print(response.choices[0].message.content)
# Out:
# 1. 상승한 지표에 대한 칭찬 전략
#    - **자신의 노력에 대해 스스로 칭찬하기**: 성취한 내용을 돌아보고, 자신이 얼마나 열심히 노력했는지 스스로에게 이야기하기.
#    - **주변 사람들과 성과 공유하기**: 가족이나 친구에게 자신의 성과를 이야기하며 긍정적인 피드백을 받기.
#
# 2. 하락한 지표에 대한 채찍 전략
#    - **목표 재설정하기**: 하락한 지표를 보며, 다음 목표를 구체적으로 세워 다시 도전하기.
#    - **학습 일지 작성하기**: 어떤 부분에서 어려움을 겪었는지 기록하고, 그 원인을 분석하여 개선 방향을 찾기.
#
# 3. 오답문제 지도 전략
#    - **오답 문제 다시 풀어보기**: 틀린 문제를 다시 풀어보며 이해도를 높이고, 올바른 해답을 찾기.
#    - **오답 노트 만들기**: 틀린 문제와 그 해설을 정리하여 반복 학습할 수 있도록 오답 노트를 작성하기.
#
# 4. 이번주 학습 교습방향 전략
#    - **주간 학습 계획 세우기**: 이번 주에 집중할 과목과 목표를 정리하여 체계적으로 학습할 계획을 세우

# %%
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "system", "content": "당신은 초등학생 맞춤 온라인 학습 멘토입니다."},
        {"role": "user", "content": prompt}
    ],
    temperature=0.3,
    max_tokens=320
)
print(response.choices[0].message.content)
# Out:
# 1. 상승한 지표에 대한 칭찬 전략
#    - 성취한 목표를 구체적으로 언급하며 칭찬하기
#    - 노력한 과정과 결과를 함께 강조하여 자부심을 느끼게 하기
#
# 2. 하락한 지표에 대한 채찍 전략
#    - 하락한 지표의 원인을 함께 분석하고 개선 방안을 모색하기
#    - 긍정적인 피드백을 통해 다시 도전할 수 있는 의지를 북돋우기
#
# 3. 오답문제 지도 전략
#    - 오답 문제를 다시 풀어보며 올바른 접근 방식을 설명하기
#    - 오답의 이유를 함께 고민하고, 비슷한 문제를 통해 연습하기
#
# 4. 이번주 학습 교습방향 전략
#    - 스스로 목표를 설정하고 계획을 세울 수 있도록 유도하기
#    - 흥미를 느낄 수 있는 주제를 선택하여 학습의 재미를 더하기
